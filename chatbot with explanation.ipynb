# %% [markdown]
# # Introduction
# * Chatbots are extremely helpful for business organizations and also the customers. The majority of people prefer to talk directly from a chatbox instead of calling service centers. Facebook released data that proved the value of bots. More than 2 billion messages are sent between people and companies monthly. The HubSpot research tells us that 71% of people want to get customer support from messaging apps. It is a quick way to get their problems solved so chatbots have a bright future in organizations.
#
# * Today we are going to build an exciting project on Chatbot. We will implement a chatbot from scratch that will be able to understand what the user is talking about and give an appropriate response.

# %% [markdown]
# # Prerequisites
# * To implement the chatbot, we will be using Keras, which is a Deep Learning library, NLTK, which is a Natural Language Processing toolkit, and some helpful libraries. Run the below command to make sure all the libraries are installed:

# %% [markdown]
# # How do Chatbots Work?
# * Chatbots are nothing but an intelligent piece of software that can interact and communicate with people just like humans. Interesting, isn’t it? So now let's see how they actually work.
#
# * All chatbots come under the NLP (Natural Language Processing) concepts. NLP is composed of two things:
#
# # NLU (Natural Language Understanding): The ability of machines to understand human language like English.
#
# # NLG (Natural Language Generation): The ability of a machine to generate text similar to human written sentences.
#
# * Imagine a user asking a question to a chatbot: “Hey, what’s on the news today?”
#
# * The chatbot will break down the user sentence into two things: intent and an entity. The intent for this sentence could be get_news as it refers to an action the user wants to perform. The entity tells specific details about the intent, so "today" will be the entity. So this way, a machine learning model is used to recognize the intents and entities of the chat.

# %% [markdown]
# # Project File Structure
# * After the project is complete, you will be left with all these files. Lets quickly go through each of them. It will give you an idea of how the project will be implemented.
#
# # Train_chatbot.py — In this file, we will build and train the deep learning model that can classify and identify what the user is asking to the bot.
#
# # Gui_Chatbot.py — This file is where we will build a graphical user interface to chat with our trained chatbot.
#
# # Intents.json — The intents file has all the data that we will use to train the model. It contains a collection of tags with their corresponding patterns and responses.
#
# # Chatbot_model.h5 — This is a hierarchical data format file in which we have stored the weights and the architecture of our trained model.
#
# # Classes.pkl — The pickle file can be used to store all the tag names to classify when we are predicting the message.
#
# # Words.pkl — The words.pkl pickle file contains all the unique words that are the vocabulary of our model.

# %% [markdown]
# # Step 1. Import Libraries and Load the Data
# * Create a new python file and name it as train_chatbot and then we are going to import all the required modules. After that, we will read the JSON data file in our Python program.

# %%
import numpy as np

from keras.models import Sequential

from keras.layers import Dense, Activation, Dropout

from keras.optimizers import SGD

import random

import nltk

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

import json

import pickle

intents_file = open('intents.json').read()
intents = json.loads(intents_file)

# %% [markdown]
# # Step 2. Preprocessing the Data
# * The model cannot take the raw data. It has to go through a lot of pre-processing for the machine to easily understand. For textual data, there are many preprocessing techniques available. The first technique is tokenizing, in which we break the sentences into words.
#
# * By observing the intents file, we can see that each tag contains a list of patterns and responses. We tokenize each pattern and add the words in a list. Also, we create a list of classes and documents to add all the intents associated with patterns.

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word

        word = nltk.word_tokenize(pattern)

        words.extend(word)        
      #add documents in the corpus

        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [(['Hi'], 'greeting'), (['Hey'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Thank', "'s", 'a', 'lot', '!'], 'thanks'), (['Which', 'items', 'do', 'you', 'have', '?'], 'items'), (['What', 'kinds', 'of', 'items', 'are', 'there', '?'], 'items'), (['What', 'do', 'you', 'sell', '?'], 'items'), (['Do', 'you', 'take', 'credit', 'cards', '?'], 'payments'), (['Do', 'you', 'accept', 'Mastercard', '?'], 'payments'), (['Can', 'I', 'pay', 'with', 'Paypal', '?'], 'payments'), (['Are', 'you', 'cash', 'only', '?'], 'payments'), (['How', 'long', 'does', 'delivery', 'take', '?'], 'delivery'), (['How', 'long', 'does', 'shipping', 'take', '?'], 'delivery'), (['When', 'do', 'I', 'get', 'my', 'delivery', '?'], 'delivery'), (['Tell', 'me', 'a', 'joke', '!'], 'funny'), (['Tell', 'me', 'something', 'funny', '!'], 'funny'), (['Do', 'you', 'know', 'a', 'joke', '?'], 'funny'), (['what', "'s", 'the', 'bill'], 'bill'), (['how', 'much', 'the', 'bill', 'is', '?'], 'bill'), (['bill', 'please', '!'], 'bill')]

# %% [markdown]
# * Another technique is Lemmatization. We can convert words into the lemma form so that we can reduce all the canonical words. For example, the words play, playing, plays, played, etc. will all be replaced with play. This way, we can reduce the number of total words in our vocabulary. So now we lemmatize each word and remove the duplicate words.

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 29 documents
# 8 classes ['bill', 'delivery', 'funny', 'goodbye', 'greeting', 'items', 'payments', 'thanks']
# 59 unique lemmatized words ["'s", 'a', 'accept', 'anyone', 'are', 'bill', 'bye', 'can', 'card', 'cash', 'credit', 'day', 'delivery', 'do', 'doe', 'funny', 'get', 'good', 'goodbye', 'have', 'hello', 'helpful', 'hey', 'hi', 'how', 'i', 'is', 'item', 'joke', 'kind', 'know', 'later', 'long', 'lot', 'mastercard', 'me', 'much', 'my', 'of', 'only', 'pay', 'paypal', 'please', 'see', 'sell', 'shipping', 'something', 'take', 'tell', 'thank', 'thanks', 'that', 'the', 'there', 'what', 'when', 'which', 'with', 'you']

# %% [markdown]
# * In the end, the words contain the vocabulary of our project and classes contain the total entities to classify. To save the python object in a file, we used the pickle.dump() method. These files will be helpful after the training is done and we predict the chats.
#
# # Step 3. Create Training and Testing Data
# * To train the model, we will convert each input pattern into numbers. First, we will lemmatize each word of the pattern and create a list of zeroes of the same length as the total number of words. We will set value 1 to only those indexes that contain the word in the patterns. In the same way, we will create the output by setting 1 to the class input the pattern belongs to.

# %%
# create the training data
training = []
# create empty array for the output
output_empty = [0] * len(classes)
# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data is created")
# Out:
# Training data is created
# <ipython-input-10-8ba07a3fe07a>:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %% [markdown]
# # Step 4. Training the Model
# * The architecture of our model will be a neural network consisting of 3 dense layers. The first layer has 128 neurons, the second one has 64 and the last layer will have the same neurons as the number of classes. The dropout layers are introduced to reduce overfitting of the model. We have used the SGD optimizer and fit the data to start the training of the model. After the training of 200 epochs is completed, we then save the trained model using the Keras model.save(“chatbot_model.h5”) function.

# %%
# deep neural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# C:\Users\UDDANDAH\Anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/200
# 6/6 [==============================] - 1s 2ms/step - loss: 2.0194 - accuracy: 0.3267
# Epoch 2/200
# 6/6 [==============================] - 0s 3ms/step - loss: 2.1137 - accuracy: 0.0227
# Epoch 3/200
# 6/6 [==============================] - 0s 3ms/step - loss: 2.0542 - accuracy: 0.1772
# Epoch 4/200
# 6/6 [==============================] - 0s 3ms/step - loss: 2.0521 - accuracy: 0.1593
# Epoch 5/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.8831 - accuracy: 0.4106
# Epoch 6/200
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7851 - accuracy: 0.5001
# Epoch 7/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.8191 - accuracy: 0.3708
# Epoch 8/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.7247 - accuracy: 0.5222
# Epoch 9/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.7401 - accuracy: 0.5494
# Epoch 10/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.5152 - accuracy: 0.7034
# Epoch 11/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.6778 - accuracy: 0.4481
# Epoch 12/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.4381 - accuracy: 0.5599
# Epoch 13/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.4478 - accuracy: 0.5664
# Epoch 14/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.1754 - accuracy: 0.7442
# Epoch 15/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.2841 - accuracy: 0.6801
# Epoch 16/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.2712 - accuracy: 0.6483
# Epoch 17/200
# 6/6 [==============================] - 0s 3ms/step - loss: 1.0775 - accuracy: 0.6799
# Epoch 18/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0497 - accuracy: 0.6991
# Epoch 19/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.9268 - accuracy: 0.6909
# Epoch 20/200
# 6/6 [==============================] - 0s 2ms/step - loss: 1.0248 - accuracy: 0.6469
# Epoch 21/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.9570 - accuracy: 0.6302
# Epoch 22/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7686 - accuracy: 0.8817
# Epoch 23/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7961 - accuracy: 0.7193
# Epoch 24/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6857 - accuracy: 0.7644
# Epoch 25/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5894 - accuracy: 0.8365
# Epoch 26/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6794 - accuracy: 0.8052
# Epoch 27/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5757 - accuracy: 0.7376
# Epoch 28/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3330 - accuracy: 0.9481
# Epoch 29/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4865 - accuracy: 0.8498
# Epoch 30/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6611 - accuracy: 0.7374
# Epoch 31/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4564 - accuracy: 0.9257
# Epoch 32/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4351 - accuracy: 0.9093
# Epoch 33/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5393 - accuracy: 0.8220
# Epoch 34/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.9308
# Epoch 35/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3641 - accuracy: 0.8173
# Epoch 36/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2868 - accuracy: 0.9436
# Epoch 37/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5391 - accuracy: 0.8222
# Epoch 38/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2279 - accuracy: 0.9746
# Epoch 39/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3952 - accuracy: 0.8588
# Epoch 40/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3732 - accuracy: 0.9451
# Epoch 41/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1686 - accuracy: 0.9773
# Epoch 42/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2141 - accuracy: 1.0000
# Epoch 43/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2229 - accuracy: 0.9128
# Epoch 44/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1344 - accuracy: 1.0000
# Epoch 45/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2551 - accuracy: 0.9773
# Epoch 46/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1861 - accuracy: 0.9773
# Epoch 47/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1307 - accuracy: 0.9901
# Epoch 48/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2559 - accuracy: 0.9746
# Epoch 49/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3278 - accuracy: 0.8927
# Epoch 50/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1993 - accuracy: 0.9901
# Epoch 51/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2296 - accuracy: 0.9535
# Epoch 52/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4333 - accuracy: 0.8306
# Epoch 53/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1528 - accuracy: 1.0000
# Epoch 54/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1514 - accuracy: 0.9844
# Epoch 55/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2247 - accuracy: 0.9522
# Epoch 56/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 57/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1072 - accuracy: 1.0000
# Epoch 58/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 1.0000
# Epoch 59/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.9901
# Epoch 60/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1582 - accuracy: 0.9535
# Epoch 61/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1470 - accuracy: 0.9773
# Epoch 62/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2447 - accuracy: 0.8784
# Epoch 63/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1579 - accuracy: 1.0000
# Epoch 64/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0819 - accuracy: 1.0000
# Epoch 65/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1305 - accuracy: 1.0000
# Epoch 66/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3197 - accuracy: 0.9249
# Epoch 67/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0806 - accuracy: 1.0000
# Epoch 68/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 1.0000
# Epoch 69/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2015 - accuracy: 0.9249
# Epoch 70/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1146 - accuracy: 0.9678
# Epoch 71/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2581 - accuracy: 0.9114
# Epoch 72/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 1.0000
# Epoch 73/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0737 - accuracy: 1.0000
# Epoch 74/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0930 - accuracy: 0.9844
# Epoch 75/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 1.0000
# Epoch 76/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1150 - accuracy: 1.0000
# Epoch 77/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0691 - accuracy: 0.9773
# Epoch 78/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1335 - accuracy: 0.9535
# Epoch 79/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 80/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1216 - accuracy: 0.9546
# Epoch 81/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1369 - accuracy: 0.9379
# Epoch 82/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0631 - accuracy: 1.0000
# Epoch 83/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 84/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 85/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 86/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0903 - accuracy: 0.9522
# Epoch 87/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0861 - accuracy: 1.0000
# Epoch 88/200
# 6/6 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 1.00 - 0s 3ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 89/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9844
# Epoch 90/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 91/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1256 - accuracy: 0.9773
# Epoch 92/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1995 - accuracy: 0.9678
# Epoch 93/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2295 - accuracy: 0.9249
# Epoch 94/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1271 - accuracy: 0.9249
# Epoch 95/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0606 - accuracy: 1.0000
# Epoch 96/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 97/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 1.0000
# Epoch 98/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0551 - accuracy: 1.0000
# Epoch 99/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 100/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 101/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0435 - accuracy: 0.9773
# Epoch 102/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1082 - accuracy: 1.0000
# Epoch 103/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0748 - accuracy: 1.0000
# Epoch 104/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2568 - accuracy: 0.9093
# Epoch 105/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 106/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0464 - accuracy: 0.9678
# Epoch 107/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 108/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 109/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 110/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 1.0000
# Epoch 111/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 112/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 113/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0608 - accuracy: 1.0000
# Epoch 114/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1821 - accuracy: 0.9308
# Epoch 115/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0688 - accuracy: 0.9674
# Epoch 116/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 117/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 118/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 119/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 120/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0607 - accuracy: 0.9901
# Epoch 121/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1185 - accuracy: 0.9901
# Epoch 122/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 123/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 124/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0459 - accuracy: 0.9535
# Epoch 125/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1193 - accuracy: 0.9379
# Epoch 126/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 127/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0510 - accuracy: 1.0000
# Epoch 128/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 1.0000
# Epoch 129/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 130/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 131/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 132/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 133/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0976 - accuracy: 0.9249
# Epoch 134/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 135/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0913 - accuracy: 0.9212
# Epoch 136/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9901
# Epoch 137/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 138/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 139/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 140/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 141/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 142/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0603 - accuracy: 1.0000
# Epoch 143/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 144/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 145/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 146/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 147/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 148/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 149/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 150/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 151/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9901
# Epoch 152/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1973 - accuracy: 0.9249
# Epoch 153/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 0.9535
# Epoch 154/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 1.0000
# Epoch 155/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 156/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 157/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 158/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2721 - accuracy: 0.9093
# Epoch 159/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 160/200
# 6/6 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 1.00 - 0s 3ms/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 161/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0970 - accuracy: 0.9535
# Epoch 162/200
# 6/6 [==============================] - ETA: 0s - loss: 0.1501 - accuracy: 1.00 - 0s 3ms/step - loss: 0.0688 - accuracy: 1.0000
# Epoch 163/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 164/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 165/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 166/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 167/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1478 - accuracy: 0.9093
# Epoch 168/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 169/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 170/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 171/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 172/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 173/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 0.9678
# Epoch 174/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 0.9773
# Epoch 175/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 176/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 177/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 178/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 179/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 180/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 181/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 182/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 183/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 0.9901
# Epoch 184/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9844
# Epoch 185/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 186/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 187/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 188/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 189/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 190/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 0.9678
# Epoch 191/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0287 - accuracy: 0.9901
# Epoch 192/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 193/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 194/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 195/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 196/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 197/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 198/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 0.9901
# Epoch 199/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 200/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0291 - accuracy: 1.0000
# model is created

# %% [markdown]
# # Step 5. Interacting With the Chatbot
# * Our model is ready to chat, so now let’s create a nice graphical user interface for our chatbot in a new file. You can name the file as gui_chatbot.py
#
# * In our GUI file, we will be using the Tkinter module to build the structure of the desktop application and then we will capture the user message and again perform some preprocessing before we input the message into our trained model.
#
# * The model will then predict the tag of the user’s message, and we will randomly select the response from the list of responses in our intents file.
#
# # Here’s the full source code for the GUI file.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))
def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))
def predict_class(sentence):
    # filter below  threshold predictions
    p = bag_of_words(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
#Creating tkinter GUI
import tkinter
from tkinter import *
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatBox.config(state=NORMAL)
        ChatBox.insert(END, "You: " + msg + '\n\n')
        ChatBox.config(foreground="#446665", font=("Verdana", 12 )) 
        ints = predict_class(msg)
        res = getResponse(ints, intents)
        
        ChatBox.insert(END, "Bot: " + res + '\n\n')           
        ChatBox.config(state=DISABLED)
        ChatBox.yview(END)
root = Tk()
root.title("hpChatbot")
root.geometry("400x500")
root.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatBox = Text(root, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatBox.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(root, command=ChatBox.yview, cursor="heart")
ChatBox['yscrollcommand'] = scrollbar.set
#Create Button to send message
SendButton = Button(root, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#f9a602", activebackground="#3c9d9b",fg='#000000',
                    command= send )
#Create the box to enter message
EntryBox = Text(root, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatBox.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
root.mainloop()
